# %% [markdown]
# # CART

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

data = {
    'Departamento': ['Ventas', 'Soporte', 'Logística', 'Ventas', 'Soporte', 'Logística'],
    'Antigüedad': [2, 5, 3, 1, 4, 6],
    'Cumplimiento de Objetivos': [80, 60, 75, 50, 85, 70],
    'Recibe Bono': ['No', 'No', 'Sí', 'No', 'Si', 'No']
}

data['Recibe Bono'] = [1 if bono == 'Sí' else 0 for bono in data['Recibe Bono']]

df = pd.DataFrame(data)

X = df[['Antigüedad', 'Cumplimiento de Objetivos']]
y = df['Recibe Bono']

cart_model = DecisionTreeClassifier(random_state=42)
cart_model.fit(X, y)

plt.figure(figsize=(12, 8))
plot_tree(cart_model, feature_names=X.columns, class_names=['No', 'Sí'], filled=True, rounded=True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

data = {
    'Departamento': ['Ventas', 'Soporte', 'Logística', 'Ventas', 'Soporte', 'Logística'],
    'Antigüedad': [2, 5, 1, 1, 4, 6], # cambio el tercer valor a 1
    'Cumplimiento de Objetivos': [80, 60, 75, 50, 85, 70],
    'Recibe Bono': ['Si', 'No', 'Sí', 'No', 'Si', 'No']
}

data['Recibe Bono'] = [1 if bono == 'Sí' else 0 for bono in data['Recibe Bono']]

df = pd.DataFrame(data)

X = df[['Antigüedad', 'Cumplimiento de Objetivos']]
y = df['Recibe Bono']

cart_model = DecisionTreeClassifier(random_state=42)
cart_model.fit(X, y)

plt.figure(figsize=(12, 8))
plot_tree(cart_model, feature_names=X.columns, class_names=['No', 'Sí'], filled=True, rounded=True)
plt.show()
